# %%
 # !pip install '/home/pybrain-0.3.3.zip'
# Out:
# WARNING: Requirement '/home/pybrain-0.3.3.zip' looks like a filename, but the file does not exist
# Processing /home/pybrain-0.3.3.zip
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/home/pybrain-0.3.3.zip'

# %%
from pybrain.tools.shortcuts import buildNetwork
from pybrain.datasets import SupervisedDataSet
from pybrain.supervised.trainers import BackpropTrainer
from pybrain.structure.modules import SoftmaxLayer
from pybrain.structure.modules import SigmoidLayer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-15a20332b42d> in <module>()
# ----> 1 from pybrain.tools.shortcuts import buildNetwork
#       2 from pybrain.datasets import SupervisedDataSet
#       3 from pybrain.supervised.trainers import BackpropTrainer
#       4 from pybrain.structure.modules import SoftmaxLayer
#       5 from pybrain.structure.modules import SigmoidLayer
#
# ModuleNotFoundError: No module named 'pybrain'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
rede = buildNetwork(2,3,1, hiddenclass=SigmoidLayer, bias=False)

# %%
print(rede['in'])

# %%
print(rede['hidden0'])

# %%
print(rede['out'])

# %%
print(rede['bias'])

# %%
dados = SupervisedDataSet(2,1)
dados.addSample((0,0), (0))
dados.addSample((1,0), (1))
dados.addSample((0,1), (1))
dados.addSample((1,1), (0))

# %%
print(dados['input'])

# %%
dados['target']

# %%
treinamento = BackpropTrainer (rede, dataset=dados, learningrate=0.01, momentum=0.06)

# %%
erro = 0
for i in range(1000):
    erro = treinamento.train()
print("Erro:", erro)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c15ea3372de1> in <module>()
#       1 erro = 0
#       2 for i in range(1000):
# ----> 3     erro = treinamento.train()
#       4 print("Erro:", erro)
#
# NameError: name 'treinamento' is not defined

# %%
val1 = rede.activate([0,0])
val1 = round(val1[0])
print(val1)

val2 = rede.activate([0,1])
val2 = round(val2[0])
print(val2)

val3 = rede.activate([1,0])
val3 = round(val3[0])
print(val3)

val4 = rede.activate([1,1])
val4 = round(val4[0])
print(val4)
